# %% [markdown]
# # tpattern — guided T-pattern analysis
#
# Find recurring patterns in **any** sequence of timed, labelled events — sport, behaviour, clinical logs, anything — test them against chance, and get a plain-English report. **No coding needed.**
#
# **Run the two cells below.** The second opens a guided panel: upload your CSV (one row per event: `observation, event, start`) → *Inspect* → the recommended settings appear → *Run*. Results, figures, editable code and a ready-to-paste Methods paragraph appear inline and download as one zip.
#
# Data format: see [SCHEMA.md](https://github.com/ajcallaway/TPattern/blob/main/SCHEMA.md). No data yet? Try [data/worldcup_goals.csv](https://github.com/ajcallaway/TPattern/blob/main/data/worldcup_goals.csv) (select **ms** for time unit).

# %%
#@title Install tpattern — run once { display-mode: "form" }
# !pip install -q tpattern[gui]

# %%
from tpattern import launch
launch()
